# %% [markdown]
# Assignment 2: Good and Bad Data Visualization

# %% [markdown]
# 1. Bad visualization:
# Q2 Sustainable Development Goals of mmediate Concern
# https://public.tableau.com/views/MyWorld2030survey_Q2bydemographicgroup/MyWorld2030survey_Q2bydemographicgroups?:language=en-US&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
#
# 1. Explaination:
#
# Definative cognitive overload. This visual is hard to understand. The main message in this graph confusing:
# Too many variables displayed, the aesthetic is not pleasant, there are a lot of information for the eyes to process at the same time.
# The filter doesn't simplify enough and create views that are as confusion
# In term of accessibility, the selection of color is challenging. There are several items in the leged with similar colors which can make hard to read and make can create confusion.
# The axis and scale are unclear
# The units is not clearly define in the graph, the relationship between number of submission and the links between the categories also unclear.
# No clear takeaway message
#
# 2. How to improve this data visualization:
#
# Identify a clear message can can be understood quickly and remove all the distracting elements that doesn't support the main message
# Clear axis identification with annotation to highlight key data point
# Use a less complicated legend taking in consideration accessibility.
# Use filters that can help the with the understanding of the data
# Make the comparison of the data clearer and easy to evaluate

# %% [markdown]
# 2. Good visualization
# Paid Media Analysis
# https://public.tableau.com/app/profile/keyrus/viz/PaidMediaAnalysisKeyrus/PaidMediaAnalysisOverview
#
# 1. Explaination:
# There are multiples chart that well labeled, with clear axis and annotation
# The filters are helpful and easy to use, and collect more specific information
# The layout of the visual is well organized, not too crowded
# I can easily understand the message, the goal is just as the title indicates as the graphs measure different metrics related to paid media for different types of alcool over the past 12 months
# The graph provide clear information withou relaying to much on color
#
# 2. How to improve this data visualization:
#
# In terms of accessibility, there is a lot of grey tones which could be an accessibility issue
# Not sure if the icons at the top are really useful
